# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('CKD.csv')
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
indep.shape
# Out:
# (399, 27)

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
#preprocessig the dataset
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
print(x_train)
# Out:
# [[ 0.48681432  1.79924415 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]
#  [ 0.30305399  0.26080096 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]
#  [-0.61574769 -0.50842064 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]
#  ...
#  [-0.43198735  0.26080096 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]
#  [-1.35078903  0.26080096 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]
#  [-0.06446668 -1.27764223 -0.68384276 ...  0.51639778 -0.52223297
#   -0.44519456]]

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}

# %%
re=grid.cv_results_
print(re)
grid_predictions = grid.predict(x_test)
# Out:
# {'mean_fit_time': array([0.57254434, 0.34556189, 0.0089644 , 0.00444837, 0.00273099,
#        0.0045619 , 0.00692205, 0.00398736, 0.00470977, 0.00471387,
#        0.00379076, 0.00360055, 0.00558324, 0.00471525, 0.0060111 ,
#        0.00259109, 0.0038868 , 0.0037097 , 0.00689754, 0.00347061,
#        0.00411062, 0.00309496, 0.00479956, 0.00349798, 0.00269666,
#        0.00351367, 0.00418911, 0.00319114, 0.00317202, 0.00341015,
#        0.00564003, 0.00340719, 0.00412984, 0.00299277, 0.00537214,
#        0.00334716, 0.00352192, 0.00438213, 0.00429654, 0.0042654 ]), 'std_fit_time': array([1.87295125e-03, 2.75654343e-01, 4.12064094e-03, 7.87052735e-04,
#        1.32052591e-03, 4.88859050e-04, 1.57411090e-03, 6.11268365e-04,
#        1.10868439e-03, 1.57843060e-03, 1.16452835e-03, 1.53492206e-03,
#        3.16090729e-03, 1.58265726e-03, 6.68677192e-04, 1.01635870e-03,
#        2.75529769e-03, 1.08481259e-03, 1.22353243e-03, 6.54209779e-04,
#        1.25263959e-03, 4.85754446e-04, 8.87057327e-04, 4.45714300e-04,
#        8.66262056e-04, 9.34607771e-04, 7.45245614e-04, 3.98206782e-04,
#        2.25471864e-04, 3.99621670e-04, 1.65201414e-03, 3.71269784e-04,
#        1.15594127e-03, 1.26698782e-06, 9.96625350e-04, 6.15899549e-04,
#        6.79737934e-04, 1.23736066e-03, 8.09540839e-04, 8.83383217e-04]), 'mean_score_time': array([0.10562444, 0.06780152, 0.00724812, 0.00677891, 0.00549936,
#        0.00556722, 0.00727658, 0.00616312, 0.005059  , 0.00648742,
#        0.00539589, 0.00733247, 0.00505929, 0.00494943, 0.00446362,
#        0.00666113, 0.00605273, 0.00554752, 0.00594187, 0.00503225,
#        0.00557299, 0.00567503, 0.00501828, 0.00443902, 0.00499516,
#        0.00489278, 0.00518918, 0.00557041, 0.00485897, 0.00564718,
#        0.00664501, 0.00500383, 0.00501618, 0.00519514, 0.0065753 ,
#        0.00492315, 0.00589242, 0.00529561, 0.00493126, 0.00372863]), 'std_score_time': array([0.00065175, 0.0472016 , 0.00141133, 0.00211904, 0.00542841,
#        0.0004103 , 0.00212954, 0.00140981, 0.00129375, 0.00137071,
#        0.00129948, 0.00521746, 0.00088346, 0.00097286, 0.00266809,
#        0.00145817, 0.00191077, 0.000729  , 0.00243989, 0.00153162,
#        0.00127644, 0.00120681, 0.0008602 , 0.00068731, 0.00070695,
#        0.00049257, 0.00085786, 0.00133889, 0.00106512, 0.00106291,
#        0.00177143, 0.00084013, 0.00088693, 0.00077366, 0.00182857,
#        0.000758  , 0.00177147, 0.00080934, 0.00083906, 0.00078636]), 'param_C': masked_array(data=[10, 10, 10, 10, 10, 10, 10, 10, 100, 100, 100, 100,
#                    100, 100, 100, 100, 1000, 1000, 1000, 1000, 1000, 1000,
#                    1000, 1000, 2000, 2000, 2000, 2000, 2000, 2000, 2000,
#                    2000, 3000, 3000, 3000, 3000, 3000, 3000, 3000, 3000],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value=999999), 'param_gamma': masked_array(data=['auto', 'auto', 'auto', 'auto', 'scale', 'scale',
#                    'scale', 'scale', 'auto', 'auto', 'auto', 'auto',
#                    'scale', 'scale', 'scale', 'scale', 'auto', 'auto',
#                    'auto', 'auto', 'scale', 'scale', 'scale', 'scale',
#                    'auto', 'auto', 'auto', 'auto', 'scale', 'scale',
#                    'scale', 'scale', 'auto', 'auto', 'auto', 'auto',
#                    'scale', 'scale', 'scale', 'scale'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_kernel': masked_array(data=['linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                    'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                    'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                    'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                    'linear', 'rbf', 'poly', 'sigmoid', 'linear', 'rbf',
#                    'poly', 'sigmoid', 'linear', 'rbf', 'poly', 'sigmoid',
#                    'linear', 'rbf', 'poly', 'sigmoid'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'C': 10, 'gamma': 'auto', 'kernel': 'linear'}, {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}, {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}, {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}, {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}, {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}, {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}, {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}, {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}, {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}, {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}, {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}, {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}, {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}, {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}, {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}, {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}, {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}, {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}, {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}, {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}, {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}, {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}, {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmoid'}, {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}, {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}, {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}, {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}, {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}, {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}, {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}, {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmoid'}, {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}, {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}, {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}, {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}, {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}, {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}, {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}, {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmoid'}], 'split0_test_score': array([0.98156912, 0.96328363, 1.        , 0.98156912, 0.98156912,
#        0.96328363, 1.        , 0.98156912, 0.98156912, 0.96328363,
#        0.96328363, 0.98156912, 0.98156912, 0.96328363, 0.96328363,
#        0.98156912, 0.98156912, 0.96328363, 0.96328363, 0.98156912,
#        0.98156912, 0.96328363, 0.96328363, 0.98156912, 0.98156912,
#        0.96328363, 0.96328363, 0.98156912, 0.98156912, 0.96328363,
#        0.96328363, 0.98156912, 0.98156912, 0.96328363, 0.96328363,
#        0.98156912, 0.98156912, 0.96328363, 0.96328363, 0.98156912]), 'split1_test_score': array([0.96263579, 0.98101383, 0.98101383, 1.        , 0.96263579,
#        0.98101383, 0.98101383, 1.        , 0.96263579, 0.98101383,
#        0.98101383, 0.9436995 , 0.96263579, 0.98101383, 0.98101383,
#        0.9436995 , 0.96263579, 0.98101383, 0.98101383, 0.9436995 ,
#        0.96263579, 0.98101383, 0.98101383, 0.9436995 , 0.96263579,
#        0.98101383, 0.98101383, 0.9436995 , 0.96263579, 0.98101383,
#        0.98101383, 0.9436995 , 0.96263579, 0.98101383, 0.98101383,
#        0.9436995 , 0.96263579, 0.98101383, 0.98101383, 0.9436995 ]), 'split2_test_score': array([0.962573  , 1.        , 1.        , 1.        , 0.962573  ,
#        1.        , 1.        , 1.        , 0.962573  , 1.        ,
#        1.        , 0.94402307, 0.962573  , 1.        , 1.        ,
#        0.94402307, 0.962573  , 1.        , 0.98121703, 0.962573  ,
#        0.962573  , 1.        , 0.98121703, 0.962573  , 0.962573  ,
#        1.        , 0.98121703, 0.962573  , 0.962573  , 1.        ,
#        0.98121703, 0.962573  , 0.962573  , 1.        , 0.98121703,
#        0.962573  , 0.962573  , 1.        , 0.98121703, 0.962573  ]), 'split3_test_score': array([0.98103098, 1.        , 1.        , 0.98103098, 0.98103098,
#        1.        , 0.98103098, 0.98103098, 0.98103098, 0.98103098,
#        1.        , 0.98103098, 0.98103098, 0.98103098, 1.        ,
#        0.98103098, 0.98103098, 0.98103098, 1.        , 0.98103098,
#        0.98103098, 0.98103098, 1.        , 0.98103098, 0.98103098,
#        0.98103098, 1.        , 0.98103098, 0.98103098, 0.98103098,
#        1.        , 0.98103098, 0.98103098, 0.98103098, 1.        ,
#        0.98103098, 0.98103098, 0.98103098, 1.        , 0.98103098]), 'split4_test_score': array([0.98121703, 1.        , 0.98121703, 1.        , 0.98121703,
#        1.        , 0.98121703, 1.        , 0.98121703, 1.        ,
#        0.98121703, 1.        , 0.98121703, 1.        , 0.98121703,
#        1.        , 0.98121703, 1.        , 0.98121703, 0.98121703,
#        0.98121703, 1.        , 0.98121703, 0.98121703, 0.98121703,
#        1.        , 0.98121703, 0.98121703, 0.98121703, 1.        ,
#        0.98121703, 0.98121703, 0.98121703, 1.        , 0.98121703,
#        0.98121703, 0.98121703, 1.        , 0.98121703, 0.98121703]), 'mean_test_score': array([0.97380519, 0.98885949, 0.99244617, 0.99252002, 0.97380519,
#        0.98885949, 0.98865237, 0.99252002, 0.97380519, 0.98506569,
#        0.9851029 , 0.97006453, 0.97380519, 0.98506569, 0.9851029 ,
#        0.97006453, 0.97380519, 0.98506569, 0.98134631, 0.97001793,
#        0.97380519, 0.98506569, 0.98134631, 0.97001793, 0.97380519,
#        0.98506569, 0.98134631, 0.97001793, 0.97380519, 0.98506569,
#        0.98134631, 0.97001793, 0.97380519, 0.98506569, 0.98134631,
#        0.97001793, 0.97380519, 0.98506569, 0.98134631, 0.97001793]), 'std_test_score': array([0.00914706, 0.01475135, 0.00925173, 0.00916265, 0.00914706,
#        0.01475135, 0.00926558, 0.00916265, 0.00914706, 0.0138074 ,
#        0.01379673, 0.02245896, 0.00914706, 0.0138074 , 0.01379673,
#        0.02245896, 0.00914706, 0.0138074 , 0.01161348, 0.01502148,
#        0.00914706, 0.0138074 , 0.01161348, 0.01502148, 0.00914706,
#        0.0138074 , 0.01161348, 0.01502148, 0.00914706, 0.0138074 ,
#        0.01161348, 0.01502148, 0.00914706, 0.0138074 , 0.01161348,
#        0.01502148, 0.00914706, 0.0138074 , 0.01161348, 0.01502148]), 'rank_test_score': array([23,  4,  3,  1, 23,  4,  6,  1, 23,  9,  7, 33, 23,  9,  7, 33, 23,
#         9, 17, 35, 23,  9, 17, 35, 23,  9, 17, 35, 23,  9, 17, 35, 23,  9,
#        17, 35, 23,  9, 17, 35])}

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)
print("confusion matrix is\n",cm)


# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

print("The confusion matrix report is\n",clf_report)
# Out:
# confusion matrix is
#  [[51  0]
#  [ 1 81]]
# The confusion matrix report is
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       1.00      0.99      0.99        82
#
#     accuracy                           0.99       133
#    macro avg       0.99      0.99      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}: 0.9924946382275899

# %%
from sklearn.svm import SVC

svc = SVC(probability=True)
svc
# Out:
# SVC(probability=True)

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_prediction.predict_proba(x_test)[:,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 from sklearn.metrics import roc_auc_score
# ----> 3 roc_auc_score(y_test,grid_predictions.predict_proba(x_test)[:,1])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'predict_proba'

# %%
table=pd.DataFrame.from_dict(re)
table
